# %%
import matplotlib.pyplot as plt
import random

# %%
def serpinski(n):
    verticals = [(0.0, 0.0), (0.5, 1.0), (1.0, 0.0)]
    x_p = []
    y_p = []
    x1, y1 = random.choice(verticals)


    for i in range(n):

        x2, y2 = random.choice(verticals)

        x1 = (x2 + x1) / 2
        y1 = (y2 + y1) / 2

        x_p.append(x1)
        y_p.append(y1)

    plt.figure(figsize=(20,15))
    plt.scatter(x_p, y_p, alpha=0.4)

# %%
serpinski(100210)
